# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
from our_implementations import OurSMOTE

# %%
X, y = make_classification(n_samples=1000, n_features=2, weights=[0.1, 0.9], n_redundant=0)
print(X.shape, y[y == 0].shape)
# Out:
# (1000, 2) (105,)

# %%
our_smote = OurSMOTE()
X_res, y_res = our_smote.fit_resample(X, y)
print(X_res.shape, y_res[y_res == 0].shape)
# Out:
# (1790, 2) (895,)

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
plt.scatter(X_res[:,0], X_res[:,1], c=y_res)
